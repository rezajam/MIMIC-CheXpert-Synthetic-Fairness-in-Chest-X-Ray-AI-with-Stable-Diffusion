# %%
import matplotlib.pyplot as plt
import numpy as np

def combined_plot(auc_total, auc_white, auc_black, auc_other, auc_male, auc_female, TITLE, fpr_or_auc):
        
        
    # Set figure size
    plt.figure(figsize=(5, 5))

    # Setting up the data for the bars
    x = ["", "Total", "", "White", "Black", "Other", "", "Male", "Female"]
    y = [None, auc_total, None, auc_white, auc_black, auc_other, None, auc_male, auc_female]

    # Colors 
    colors = ["", "green", "", "white", "black", "blue", "", "#3274A1", "#E1812C"]
    edgecolors = ["", "black", "", "black", "black", "black", "", "#3274A1", "#E1812C"]
    # Plot the bars
    for i in range(len(x)):
        if y[i] is not None:  
            plt.bar(i, y[i], color=colors[i], edgecolor=edgecolors[i])

    # Add value labels under the bars
    for i in range(len(x)):
        if y[i] is not None:  
            plt.text(i, y[i] + 0.0025, f"{y[i]:.4f}", ha='center')

    # Add grid, labels, big title
    plt.grid(axis='y', linestyle='--', color='grey', alpha=0.5)
    plt.title(f"{fpr_or_auc} for {TITLE}", fontsize=14)
    plt.xlabel("")
    plt.ylabel(f"{fpr_or_auc}")
    if fpr_or_auc == "FPR":
        plt.ylim(0.15, 0.35)
    elif fpr_or_auc == "AUC":
        plt.ylim(0.7, 0.9)

    # Adjust x-axis labels
    plt.xticks(range(len(x)), x, rotation=0)

    # Show plot
    plt.tight_layout()
    plt.show()

# %%
import json

# ---------------------------------------------------------------------------- #
#                                 CHEXPERT                                     #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_CHEXPERT.json", "r") as json_file:
    data = json.load(json_file)




# Access individual dictionaries
fpr_all_CHEXPERT = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_CHEXPERT = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_CHEXPERT = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_CHEXPERT = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_CHEXPERT = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_CHEXPERT = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR CHEXPERT All:", fpr_all_CHEXPERT)
print("FPR CHEXPERT White:", fpr_white_CHEXPERT)


label_names = ["No Finding"]


combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'], "CheXpert", "FPR")


# ----------------------------------------------------------------------------------------------------------------------------------------

import json

# ---------------------------------------------------------------------------- #
#                                      CHEXPERT                                #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_CHEXPERT.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_CHEXPERT = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_CHEXPERT = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_CHEXPERT = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_CHEXPERT = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_CHEXPERT = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_CHEXPERT = {int(k): v for k, v in data["my_auc_female"].items()}



print("AUC CHEXPERT All:", auc_all_CHEXPERT)
print("AUC CHEXPERT White:", auc_white_CHEXPERT)


label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'], "CHEXPERT", "AUC")
# Out:
# FPR CHEXPERT All: {0: 0.20008334134692438, 1: 0.1125873253493014, 2: 0.10104270109235353, 3: 0.270594653573377, 4: 0.11804001356391998, 5: 0.27531416400425984}
# FPR CHEXPERT White: {0: 0.21697317361228277, 1: 0.11847500831209132, 2: 0.10841275216486866, 3: 0.31169386881838745, 4: 0.14085832601330153, 5: 0.24602354885354266}
# AUC CHEXPERT All: {0: 0.7701460474049713, 1: 0.8745980544060518, 2: 0.7929855544774607, 3: 0.7992962553506232, 4: 0.9130137731648036, 5: 0.8360972471092983}
# AUC CHEXPERT White: {0: 0.7496589928162072, 1: 0.8665082976424145, 2: 0.7861409816271043, 3: 0.7795064379266052, 4: 0.9001146748939743, 5: 0.8188543356870053}

# %%
import json

# ---------------------------------------------------------------------------- #
#                                 CHEXPERT  +  SYN                             #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_CHEXPERT_SYN.json", "r") as json_file:
    data = json.load(json_file)




# Access individual dictionaries
fpr_all_CHEXPERT_SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_CHEXPERT_SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_CHEXPERT_SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_CHEXPERT_SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_CHEXPERT_SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_CHEXPERT_SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR CHEXPERT_SYN All:", fpr_all_CHEXPERT_SYN)
print("FPR CHEXPERT_SYN White:", fpr_white_CHEXPERT_SYN)


label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'], "CheXpert + SYN", "FPR")


# ----------------------------------------------------------------------------------------------------------------------------------------


# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_CHEXPERT_SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_CHEXPERT_SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_CHEXPERT_SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_CHEXPERT_SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_CHEXPERT_SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_CHEXPERT_SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_CHEXPERT_SYN = {int(k): v for k, v in data["my_auc_female"].items()}

print("AUC CHEXPERT_SYN All:", auc_all_CHEXPERT_SYN)
print("AUC CHEXPERT_SYN White:", auc_white_CHEXPERT_SYN)


label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'], "CHEXPERT + SYN", "AUC")
# Out:
# FPR CHEXPERT_SYN All: {0: 0.2039298650511267, 1: 0.11495758483033933, 2: 0.0915259847732539, 3: 0.22316557555919259, 4: 0.12261783655476433, 5: 0.24749733759318424}
# FPR CHEXPERT_SYN White: {0: 0.22782745627355042, 1: 0.12440430012191067, 2: 0.09752793769048425, 3: 0.25478329971269637, 4: 0.14656795080938637, 5: 0.21579563451077602}
# AUC CHEXPERT_SYN All: {0: 0.8060569501257795, 1: 0.8857651537451603, 2: 0.8016251232616511, 3: 0.809654178272798, 4: 0.916514026844025, 5: 0.8426139143057038}
# AUC CHEXPERT_SYN White: {0: 0.7897362877279425, 1: 0.8778695927345176, 2: 0.7996190804296208, 3: 0.792257407063738, 4: 0.9046109744391351, 5: 0.8267248617741504}

# %%
import json

# ---------------------------------------------------------------------------- #
#                                     MIMIC                                    #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC All:", fpr_all_MIMIC)
print("FPR MIMIC White:", fpr_white_MIMIC)

label_names = ["No Finding"]

combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'], "MIMIC", "FPR")

# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #
# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC = {int(k): v for k, v in data["my_auc_female"].items()}


print("AUC MIMIC All:", auc_all_MIMIC)
print("AUC MIMIC White:", auc_white_MIMIC)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'], "MIMIC", "AUC")
# Out:
# FPR MIMIC All: {0: 0.18498573580793026, 1: 0.1313934630738523, 2: 0.06441023943506566, 3: 0.2149822695035461, 4: 0.11685317056629366, 5: 0.21989350372736954}
# FPR MIMIC White: {0: 0.19728924132500983, 1: 0.14673611880749196, 2: 0.06980794349571864, 3: 0.2527660614952014, 4: 0.14136027105031998, 5: 0.19362390690628659}
# AUC MIMIC All: {0: 0.8285087515246505, 1: 0.8943514855139292, 2: 0.831658966666635, 3: 0.8222847431504154, 4: 0.9234469203558643, 5: 0.8647304677998868}
# AUC MIMIC White: {0: 0.8135996089723384, 1: 0.8866113167654643, 2: 0.8247179106301504, 3: 0.8065141346419281, 4: 0.9101155240221452, 5: 0.8514315477441443}

# %%
import json

# ---------------------------------------------------------------------------- #
#                                      SYNTH                                   #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_SYNTH.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR SYN All:", fpr_all_SYN)
print("FPR SYN White:", fpr_white_SYN)


label_names = ["No Finding"]

combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'], "SYNTHETIC", "FPR")

# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #
# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_SYNTH.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_SYN = {int(k): v for k, v in data["my_auc_female"].items()}

print("AUC SYN All:", auc_all_SYN)
print("AUC SYN White:", auc_white_SYN)


label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'], "SYNTHETIC", "AUC")
# Out:
# FPR SYN All: {0: 0.18860787896272077, 1: 0.1316429640718563, 2: 0.07508551252344699, 3: 0.24502182214948173, 4: 0.12614445574771108, 5: 0.2808093716719915}
# FPR SYN White: {0: 0.2110679939261009, 1: 0.14252465920425578, 2: 0.07779014077693387, 3: 0.2827189926034599, 4: 0.15064625423516126, 5: 0.25717826895269574}
# AUC SYN All: {0: 0.7935237160829636, 1: 0.8624637393595689, 2: 0.7985588069125797, 3: 0.7990339719492268, 4: 0.8987086468160908, 5: 0.8405800721902413}
# AUC SYN White: {0: 0.7775792709808365, 1: 0.8570597441685955, 2: 0.7958160087447634, 3: 0.7847490244571935, 4: 0.8853367176515679, 5: 0.829344405480859}

# %%
import json

# ---------------------------------------------------------------------------- #
#                               MIMIC + CHEXPERT                               #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC_CHEXPERT.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC_CHEXPERT = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC_CHEXPERT = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC_CHEXPERT = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC_CHEXPERT = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC_CHEXPERT = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC_CHEXPERT = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC_CHEXPERT All:", fpr_all_MIMIC_CHEXPERT)
print("FPR MIMIC_CHEXPERT White:", fpr_white_MIMIC_CHEXPERT)

label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'],  "MIMIC + CheXpert", "FPR")


# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC_CHEXPERT.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC_CHEXPERT = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC_CHEXPERT = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC_CHEXPERT = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC_CHEXPERT = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC_CHEXPERT = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC_CHEXPERT = {int(k): v for k, v in data["my_auc_female"].items()}

print("AUC MIMIC_CHEXPERT All:", auc_all_MIMIC_CHEXPERT)
print("AUC MIMIC_CHEXPERT White:", auc_white_MIMIC_CHEXPERT)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'],  "MIMIC + CheXpert", "AUC")
# Out:
# FPR MIMIC_CHEXPERT All: {0: 0.18251754976440043, 1: 0.12029066866267465, 2: 0.09651881275515833, 3: 0.2321331151118385, 4: 0.1136656493726687, 5: 0.23395101171458998}
# FPR MIMIC_CHEXPERT White: {0: 0.19790787919689556, 1: 0.13188518231186966, 2: 0.10275264863818877, 3: 0.2719603887768201, 4: 0.13539967373572595, 5: 0.2077394477724988}
# AUC MIMIC_CHEXPERT All: {0: 0.8269404007010183, 1: 0.8919613065014311, 2: 0.8242048872632104, 3: 0.8229478478987001, 4: 0.9230209882457943, 5: 0.8618699191573591}
# AUC MIMIC_CHEXPERT White: {0: 0.8087476563314977, 1: 0.883078503296415, 2: 0.8169290254169157, 3: 0.8068106022180068, 4: 0.9103355901133685, 5: 0.8461444386355637}

# %%
import json

# ---------------------------------------------------------------------------- #
#                               MIMIC + SYN                                    #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC_SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC_SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC_SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC_SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC_SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC_SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC_SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC_SYN All:", fpr_all_MIMIC_SYN)
print("FPR MIMIC_SYN White:", fpr_white_MIMIC_SYN)

label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'],  "MIMIC + SYN", "FPR")

# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #


# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC_SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC_SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC_SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC_SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC_SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC_SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC_SYN = {int(k): v for k, v in data["my_auc_female"].items()}

print("AUC MIMIC_SYN All:", auc_all_MIMIC_SYN)
print("AUC MIMIC_SYN White:", auc_white_MIMIC_SYN)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'],  "MIMIC + SYN", "AUC")
# Out:
# FPR MIMIC_SYN All: {0: 0.17370259960893675, 1: 0.10878243512974052, 2: 0.07246496745007172, 3: 0.21351609383524278, 4: 0.10552729738894541, 5: 0.22210862619808305}
# FPR MIMIC_SYN White: {0: 0.18418536640233957, 1: 0.11786545494846504, 2: 0.07604857046103236, 3: 0.2490983556452106, 4: 0.12761952566194001, 5: 0.1986504165805963}
# AUC MIMIC_SYN All: {0: 0.831094476862118, 1: 0.8933715020934134, 2: 0.8207349868178403, 3: 0.8201979919098052, 4: 0.9235791490394315, 5: 0.8638539988925831}
# AUC MIMIC_SYN White: {0: 0.8149876088953552, 1: 0.8870879719354582, 2: 0.8168006167642081, 3: 0.8030619605308233, 4: 0.9109978899120121, 5: 0.8514225786542791}

# %%
import json

# ---------------------------------------------------------------------------- #
#                               MIMIC + 75% SYN                                #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC_75SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC_75SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC_75SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC_75SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC_75SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC_75SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC_75SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC_75SYN All:", fpr_all_MIMIC_75SYN)
print("FPR MIMIC_75SYN White:", fpr_white_MIMIC_75SYN)

label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'],  "MIMIC + 75% SYN", "FPR")



# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #


# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC_75SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC_75SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC_75SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC_75SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC_75SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC_75SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC_75SYN = {int(k): v for k, v in data["my_auc_female"].items()}

print("AUC MIMIC_75SYN All:", auc_all_MIMIC_75SYN)
print("AUC MIMIC_75SYN White:", auc_white_MIMIC_75SYN)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'],  "MIMIC + 75% SYN", "AUC")
# Out:
# FPR MIMIC_75SYN All: {0: 0.16825335769465014, 1: 0.12050898203592815, 2: 0.07254772150502041, 3: 0.23646344789961812, 4: 0.10915564598168871, 5: 0.21405750798722045}
# FPR MIMIC_75SYN White: {0: 0.1848040042742253, 1: 0.13388008422919206, 2: 0.0766290938996662, 3: 0.2731218289626505, 4: 0.13245074664324258, 5: 0.19135164910831096}
# AUC MIMIC_75SYN All: {0: 0.8306515765790712, 1: 0.8924349238709185, 2: 0.8285905261387416, 3: 0.8248365285438699, 4: 0.9242128877856635, 5: 0.8645698945940123}
# AUC MIMIC_75SYN White: {0: 0.8149271604641499, 1: 0.8847306088515595, 2: 0.8236458158269817, 3: 0.8081220886728757, 4: 0.9112620600073588, 5: 0.8503973287173596}

# %%
import json

# ---------------------------------------------------------------------------- #
#                               MIMIC + 50% SYN                                #
# ---------------------------------------------------------------------------- #

# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC_50SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC_50SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC_50SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC_50SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC_50SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC_50SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC_50SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC_50SYN All:", fpr_all_MIMIC_50SYN)
print("FPR MIMIC_50SYN White:", fpr_white_MIMIC_50SYN)

label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'],  "MIMIC + 50% SYN", "FPR")



# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #


# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC_50SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC_50SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC_50SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC_50SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC_50SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC_50SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC_50SYN = {int(k): v for k, v in data["my_auc_female"].items()}

print("AUC MIMIC_50SYN All:", auc_all_MIMIC_50SYN)
print("AUC MIMIC_50SYN White:", auc_white_MIMIC_50SYN)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'],  "MIMIC + 50% SYN", "AUC")
# Out:
# FPR MIMIC_50SYN All: {0: 0.18976183607398148, 1: 0.11667290419161677, 2: 0.08192651439920556, 3: 0.2342812329514457, 4: 0.12461851475076297, 5: 0.21576144834930777}
# FPR MIMIC_50SYN White: {0: 0.20341938023733197, 1: 0.13049983375817356, 2: 0.08698176188863625, 3: 0.26707011431016564, 4: 0.15252854812398042, 5: 0.19031880465468567}
# AUC MIMIC_50SYN All: {0: 0.8331301873716468, 1: 0.8928981053383919, 2: 0.8275054857165078, 3: 0.8241416872560746, 4: 0.9248956061993997, 5: 0.8653119150566555}
# AUC MIMIC_50SYN White: {0: 0.8166805843338364, 1: 0.8851706415981826, 2: 0.8208777313054535, 3: 0.8070723610781431, 4: 0.9121726591847445, 5: 0.8511698486513458}

# %%
import json

# ---------------------------------------------------------------------------- #
#                               MIMIC + 25% SYN                                #
# ---------------------------------------------------------------------------- #

# Load the JSON file                                                 fpr_MIMIC_25SYN
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC_25SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC_25SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC_25SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC_25SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC_25SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC_25SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC_25SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC_25SYN All:", fpr_all_MIMIC_25SYN)
print("FPR MIMIC_25SYN White:", fpr_white_MIMIC_25SYN)

label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'],  "MIMIC + 25% SYN", "FPR")



# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #


# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC_25SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC_25SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC_25SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC_25SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC_25SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC_25SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC_25SYN = {int(k): v for k, v in data["my_auc_female"].items()}

print("AUC MIMIC_25SYN All:", auc_all_MIMIC_25SYN)
print("AUC MIMIC_25SYN White:", auc_white_MIMIC_25SYN)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'],  "MIMIC + 25% SYN", "AUC")
# Out:
# FPR MIMIC_25SYN All: {0: 0.18665256274641792, 1: 0.10039296407185629, 2: 0.0550590312258634, 3: 0.19759274413529732, 4: 0.10417090539165819, 5: 0.2169116080937167}
# FPR MIMIC_25SYN White: {0: 0.19762668016422025, 1: 0.1063393549817134, 2: 0.05718155870543273, 3: 0.23528333027691178, 4: 0.12874890199523154, 5: 0.19513874543827034}
# AUC MIMIC_25SYN All: {0: 0.8320222397760155, 1: 0.8907237710511999, 2: 0.8248374183169264, 3: 0.822822567663089, 4: 0.9248449285479199, 5: 0.8644183607598994}
# AUC MIMIC_25SYN White: {0: 0.8167590504713697, 1: 0.8842254925092734, 2: 0.8172280676930596, 3: 0.8057694765282115, 4: 0.9123308059441304, 5: 0.849516502236789}

# %%
import json

# ---------------------------------------------------------------------------- #
#                               MIMIC + 01% SYN                                #
# ---------------------------------------------------------------------------- #

# Load the JSON file                                                 fpr_MIMIC_01SYN
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC_01SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC_01SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC_01SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC_01SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC_01SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC_01SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC_01SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC_01SYN All:", fpr_all_MIMIC_01SYN)
print("FPR MIMIC_01SYN White:", fpr_white_MIMIC_01SYN)

label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'],  "MIMIC + 1% SYN", "FPR")



# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #


# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC_01SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC_01SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC_01SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC_01SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC_01SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC_01SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC_01SYN = {int(k): v for k, v in data["my_auc_female"].items()}

print("AUC MIMIC_01SYN All:", auc_all_MIMIC_01SYN)
print("AUC MIMIC_01SYN White:", auc_white_MIMIC_01SYN)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'],  "MIMIC + 1% SYN", "AUC")
# Out:
# FPR MIMIC_01SYN All: {0: 0.17302945796070135, 1: 0.12247380239520958, 2: 0.10937327595718857, 3: 0.22613202400436444, 4: 0.10461173279077654, 5: 0.2177209797657082}
# FPR MIMIC_01SYN White: {0: 0.1903155053146617, 1: 0.13526543278288816, 2: 0.11562091819457211, 3: 0.2616908123968458, 4: 0.12435688292132012, 5: 0.19204021207739447}
# AUC MIMIC_01SYN All: {0: 0.8306205631991044, 1: 0.8925810376694676, 2: 0.8240363756632575, 3: 0.8242948906466385, 4: 0.9230772129220363, 5: 0.8638511856417206}
# AUC MIMIC_01SYN White: {0: 0.8135566690188534, 1: 0.8863434403706287, 2: 0.8204411922206504, 3: 0.8071563846272657, 4: 0.910877452916762, 5: 0.8498230958708126}

# %%
import json

# ---------------------------------------------------------------------------- #
#                               MIMIC + 05% SYN                                #
# ---------------------------------------------------------------------------- #

# Load the JSON file                                                 fpr_MIMIC_05SYN
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC_05SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC_05SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC_05SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC_05SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC_05SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC_05SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC_05SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC_05SYN All:", fpr_all_MIMIC_05SYN)
print("FPR MIMIC_05SYN White:", fpr_white_MIMIC_05SYN)

label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'],  "MIMIC + 5% SYN", "FPR")



# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #


# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC_05SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC_05SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC_05SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC_05SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC_05SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC_05SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC_05SYN = {int(k): v for k, v in data["my_auc_female"].items()}


print("AUC MIMIC_05SYN All:", auc_all_MIMIC_05SYN)
print("AUC MIMIC_05SYN White:", auc_white_MIMIC_05SYN)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'],  "MIMIC + 5% SYN", "AUC")
# Out:
# FPR MIMIC_05SYN All: {0: 0.20380164759431996, 1: 0.1187312874251497, 2: 0.06653426017874876, 3: 0.22851882160392797, 4: 0.10966429298067142, 5: 0.2261128860489883}
# FPR MIMIC_05SYN White: {0: 0.2251279455598673, 1: 0.13022276404743433, 2: 0.06898553529098737, 3: 0.26743688489516476, 4: 0.13358012297653407, 5: 0.20305721958273085}
# AUC MIMIC_05SYN All: {0: 0.8279110004888551, 1: 0.8879606418877861, 2: 0.8223773030840784, 3: 0.8212589713918702, 4: 0.9246801201865064, 5: 0.8627555671972846}
# AUC MIMIC_05SYN White: {0: 0.8127355378888175, 1: 0.8797945365346185, 2: 0.8150208202661963, 3: 0.8039183135240968, 4: 0.9120487925007368, 5: 0.8477096454554613}

# %%
import json

# ---------------------------------------------------------------------------- #
#                               MIMIC + 10% SYN                                #
# ---------------------------------------------------------------------------- #

# Load the JSON file                                                 fpr_MIMIC_10SYN
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/FPR_MIMIC_10SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
fpr_all_MIMIC_10SYN = {int(k): v for k, v in data["fpr_all"].items()}
fpr_white_MIMIC_10SYN = {int(k): v for k, v in data["fpr_white"].items()}
fpr_black_MIMIC_10SYN = {int(k): v for k, v in data["fpr_black"].items()}
fpr_other_MIMIC_10SYN = {int(k): v for k, v in data["fpr_other"].items()}
fpr_male_MIMIC_10SYN = {int(k): v for k, v in data["fpr_male"].items()}
fpr_female_MIMIC_10SYN = {int(k): v for k, v in data["fpr_female"].items()}

print("FPR MIMIC_10SYN All:", fpr_all_MIMIC_10SYN)
print("FPR MIMIC_10SYN White:", fpr_white_MIMIC_10SYN)

label_names = ["No Finding"]
combined_plot(data["fpr_all"]['5'], data["fpr_white"]['5'], data["fpr_black"]['5'], data["fpr_other"]['5'], data["fpr_male"]['5'], data["fpr_female"]['5'],  "MIMIC + 10% SYN", "FPR")



# -------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------- #
#                                      AUC                                     #
# ---------------------------------------------------------------------------- #


# Load the JSON file
with open("/local/home/rezajam/fairness_on_embeddings/FINAL_ANALYSIS/AUC_MIMIC_10SYN.json", "r") as json_file:
    data = json.load(json_file)

# Access individual dictionaries
auc_all_MIMIC_10SYN = {int(k): v for k, v in data["my_auc_all"].items()}
auc_white_MIMIC_10SYN = {int(k): v for k, v in data["my_auc_white"].items()}
auc_black_MIMIC_10SYN = {int(k): v for k, v in data["my_auc_black"].items()}
auc_other_MIMIC_10SYN = {int(k): v for k, v in data["my_auc_other"].items()}
auc_male_MIMIC_10SYN = {int(k): v for k, v in data["my_auc_male"].items()}
auc_female_MIMIC_10SYN = {int(k): v for k, v in data["my_auc_female"].items()}


print("AUC MIMIC_10SYN All:", auc_all_MIMIC_10SYN)
print("AUC MIMIC_10SYN White:", auc_white_MIMIC_10SYN)

label_names = ["No Finding"]
combined_plot(data["my_auc_all"]['5'], data["my_auc_white"]['5'], data["my_auc_black"]['5'], data["my_auc_other"]['5'], data["my_auc_male"]['5'], data["my_auc_female"]['5'],  "MIMIC + 10% SYN", "AUC")
# Out:
# FPR MIMIC_10SYN All: {0: 0.19235823957431805, 1: 0.1218812375249501, 2: 0.07122365662584133, 3: 0.20557146753955263, 4: 0.10545947778908105, 5: 0.2242811501597444}
# FPR MIMIC_10SYN White: {0: 0.20949327934311907, 1: 0.1320514241383132, 2: 0.07319433022108268, 3: 0.2371171832019072, 4: 0.1282469569582131, 5: 0.2018178062383805}
# AUC MIMIC_10SYN All: {0: 0.8283785216639526, 1: 0.8932790422914914, 2: 0.8242134037383019, 3: 0.8230668722164957, 4: 0.9242713611995573, 5: 0.8643138151280912}
# AUC MIMIC_10SYN White: {0: 0.812709582207133, 1: 0.8870638454354314, 2: 0.8180012880014249, 3: 0.807569630295085, 4: 0.9114147035733455, 5: 0.8503499059433588}

# %%
def plot_auc_barchart_experiments(fpr_dicts, label_names, TITLE, fpr_or_auc):

    n_experiments = len(fpr_dicts)
    x = np.arange(n_experiments) 

    # Bar width
    width = 0.2

    # Create the figure and axes
    fig, ax = plt.subplots(figsize=(25, 8))

    # Loop over all experiments and plot bars
    for i, fpr in enumerate(fpr_dicts):
        bars_all = ax.bar(x[i] - 1.5 * width, fpr[0], width, label='Total' if i == 0 else "", color="green", edgecolor="black")
        bars_white = ax.bar(x[i] - 0.5 * width, fpr[1], width, label='White' if i == 0 else "", color="white", edgecolor="black")
        bars_black = ax.bar(x[i] + 0.5 * width, fpr[2], width, label='Black' if i == 0 else "", color="black", edgecolor="black")
        bars_other = ax.bar(x[i] + 1.5 * width, fpr[3], width, label='Other' if i == 0 else "", color="blue", edgecolor="black")
        
        # THEN FOR EACH, Add values on top of bars
        for bar in [bars_all, bars_white, bars_black, bars_other]:
            ax.bar_label(bar, fmt='%.4f', padding=3)

            
    # Add labels, title, legend
    ax.set_ylabel(f"{fpr_or_auc}", fontsize=14)
    ax.set_title(f"{TITLE}: {fpr_or_auc} Comparison Across Experiments", fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(label_names, fontsize=12)
    
    ax.legend(loc='upper left', fontsize=12)

    if fpr_or_auc == "FPR":
         ax.set_ylim(0.15, 0.35)
    elif fpr_or_auc == "AUC":
         ax.set_ylim(0.7, 0.9)
    # ax.set_ylim(0.15, 0.35) # Zoom in y-axis 

    # Display 
    plt.grid(axis='y', linestyle='--', color='grey', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
def plot_auc_barchart_experiments_gender(fpr_dicts, label_names, TITLE,fpr_or_auc):

    n_experiments = len(fpr_dicts)
    x = np.arange(n_experiments)  

    # Bar width
    width = 0.15

    # Create the figure and axes
    fig, ax = plt.subplots(figsize=(25, 8))

    # Loop over all experiments and plot bars
    for i, fpr in enumerate(fpr_dicts):
        bars_total = ax.bar(x[i] - 1.5 * width, fpr[0], width, label='Total' if i == 0 else "", color="green")
        bars_white = ax.bar(x[i] - 0.5 * width, fpr[4], width, label='Male' if i == 0 else "", color="#E1812C")
        bars_black = ax.bar(x[i] + 0.5 * width, fpr[5], width, label='Female' if i == 0 else "", color="#3274A1")

        # THEN FOR EACH, Add values on top of bars
        for bar in [bars_total, bars_white, bars_black]:
            ax.bar_label(bar, fmt='%.4f', padding=3)

    # Add labels, title, and legend
    ax.set_ylabel("FPR", fontsize=14)
    ax.set_title(f"{TITLE}: {fpr_or_auc} Comparison Across Experiments", fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(label_names, fontsize=12)
    
    ax.legend(loc='upper left', fontsize=12)

    if fpr_or_auc == "FPR":
         ax.set_ylim(0.15, 0.35)
    elif fpr_or_auc == "AUC":
         ax.set_ylim(0.8, 0.9)
    # ax.set_ylim(0.15, 0.35)  # Zoom in y-axis 

    # Display 
    plt.grid(axis='y', linestyle='--', color='grey', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
label_names = ["Experiment-1","Experiment-2","Experiment-3","Experiment-4"]
# fpr_black_MIMIC


fpr_MIMIC = {
    0: fpr_all_MIMIC[5],
    1: fpr_white_MIMIC[5],
    2: fpr_black_MIMIC[5],
    3: fpr_other_MIMIC[5],
    4: fpr_male_MIMIC[5],
    5: fpr_female_MIMIC[5]
}

fpr_SYN = {
    0: fpr_all_SYN[5],
    1: fpr_white_SYN[5],
    2: fpr_black_SYN[5],
    3: fpr_other_SYN[5],
    4: fpr_male_SYN[5],
    5: fpr_female_SYN[5]
}

fpr_MIMIC_CHEXPERT = {
    0: fpr_all_MIMIC_CHEXPERT[5],
    1: fpr_white_MIMIC_CHEXPERT[5],
    2: fpr_black_MIMIC_CHEXPERT[5],
    3: fpr_other_MIMIC_CHEXPERT[5],
    4: fpr_male_MIMIC_CHEXPERT[5],
    5: fpr_female_MIMIC_CHEXPERT[5]
}

fpr_MIMIC_SYN = {
    0: fpr_all_MIMIC_SYN[5],
    1: fpr_white_MIMIC_SYN[5],
    2: fpr_black_MIMIC_SYN[5],
    3: fpr_other_MIMIC_SYN[5],
    4: fpr_male_MIMIC_SYN[5],
    5: fpr_female_MIMIC_SYN[5]
}

fpr_CHEXPERT = {
    0: fpr_all_CHEXPERT[5],
    1: fpr_white_CHEXPERT[5],
    2: fpr_black_CHEXPERT[5],
    3: fpr_other_CHEXPERT[5],
    4: fpr_male_CHEXPERT[5],
    5: fpr_female_CHEXPERT[5]
}

fpr_CHEXPERT_SYN = {
    0: fpr_all_CHEXPERT_SYN[5],
    1: fpr_white_CHEXPERT_SYN[5],
    2: fpr_black_CHEXPERT_SYN[5],
    3: fpr_other_CHEXPERT_SYN[5],
    4: fpr_male_CHEXPERT_SYN[5],
    5: fpr_female_CHEXPERT_SYN[5]
}

fpr_MIMIC_75SYN = {
    0: fpr_all_MIMIC_75SYN[5],
    1: fpr_white_MIMIC_75SYN[5],
    2: fpr_black_MIMIC_75SYN[5],
    3: fpr_other_MIMIC_75SYN[5],
    4: fpr_male_MIMIC_75SYN[5],
    5: fpr_female_MIMIC_75SYN[5]
}

fpr_MIMIC_50SYN = {
    0: fpr_all_MIMIC_50SYN[5],
    1: fpr_white_MIMIC_50SYN[5],
    2: fpr_black_MIMIC_50SYN[5],
    3: fpr_other_MIMIC_50SYN[5],
    4: fpr_male_MIMIC_50SYN[5],
    5: fpr_female_MIMIC_50SYN[5]
}

fpr_MIMIC_25SYN = {
    0: fpr_all_MIMIC_25SYN[5],
    1: fpr_white_MIMIC_25SYN[5],
    2: fpr_black_MIMIC_25SYN[5],
    3: fpr_other_MIMIC_25SYN[5],
    4: fpr_male_MIMIC_25SYN[5],
    5: fpr_female_MIMIC_25SYN[5]
}

fpr_MIMIC_01SYN = {
    0: fpr_all_MIMIC_01SYN[5],
    1: fpr_white_MIMIC_01SYN[5],
    2: fpr_black_MIMIC_01SYN[5],
    3: fpr_other_MIMIC_01SYN[5],
    4: fpr_male_MIMIC_01SYN[5],
    5: fpr_female_MIMIC_01SYN[5]
}

fpr_MIMIC_05SYN = {
    0: fpr_all_MIMIC_05SYN[5],
    1: fpr_white_MIMIC_05SYN[5],
    2: fpr_black_MIMIC_05SYN[5],
    3: fpr_other_MIMIC_05SYN[5],
    4: fpr_male_MIMIC_05SYN[5],
    5: fpr_female_MIMIC_05SYN[5]
}

fpr_MIMIC_10SYN = {
    0: fpr_all_MIMIC_10SYN[5],
    1: fpr_white_MIMIC_10SYN[5],
    2: fpr_black_MIMIC_10SYN[5],
    3: fpr_other_MIMIC_10SYN[5],
    4: fpr_male_MIMIC_10SYN[5],
    5: fpr_female_MIMIC_10SYN[5]
}


fpr_MIMIC_SYN
# fpr_MIMIC_dict = [fpr_black_MIMIC[i]  for i in range(len(label_names))]
# fpr_SYN_dict = [fpr_black_SYN[i] for i in range(len(label_names))]
# fpr_MIMIC_SYN_dict = [fpr_black_MIMIC_SYN[i] for i in range(len(label_names))]
# fpr_MIMIC_CHEXPERT_dict = [fpr_black_MIMIC_CHEXPERT[i] for i in range(len(label_names))]
# # fpr_dicts = [fpr_MIMIC, fpr_SYN, fpr_MIMIC_SYN, fpr_MIMIC_CHEXPERT]
label_names = ["MIMIC", "Synthetic", "MIMIC + CheXpert", "CheXpert", "CheXpert + SYN", "MIMIC + SYN", "MIMIC + 75% SYN", "MIMIC + 50% SYN", "MIMIC + 25% SYN", "MIMIC + 10% SYN", "MIMIC + 5% SYN", "MIMIC + 1% SYN"]
fpr_dicts = [fpr_MIMIC, fpr_SYN, fpr_MIMIC_CHEXPERT, fpr_CHEXPERT, fpr_CHEXPERT_SYN, fpr_MIMIC_SYN, fpr_MIMIC_75SYN, fpr_MIMIC_50SYN, fpr_MIMIC_25SYN, fpr_MIMIC_10SYN, fpr_MIMIC_05SYN, fpr_MIMIC_01SYN]
fpr_dicts
# # Plot the data
plot_auc_barchart_experiments(fpr_dicts, label_names, "12 EXPERIMENTS", "FPR")


label_names = ["MIMIC", "MIMIC + Synthetic", "MIMIC + 75% Synthetic", "MIMIC + 50% Synthetic", "MIMIC + 25% Synthetic", "MIMIC + 10% Synthetic", "MIMIC + 5% Synthetic", "MIMIC + 1% Synthetic"]
fpr_dicts = [fpr_MIMIC, fpr_MIMIC_SYN, fpr_MIMIC_75SYN, fpr_MIMIC_50SYN, fpr_MIMIC_25SYN, fpr_MIMIC_10SYN, fpr_MIMIC_05SYN, fpr_MIMIC_01SYN]
fpr_dicts
# # Plot the data
plot_auc_barchart_experiments(fpr_dicts, label_names, "[MIMIC] And All The [MIMIC + Synthetic] Experiments", "FPR")


plot_auc_barchart_experiments_gender(fpr_dicts, label_names, "6 EXPERIMENTS", "FPR")

# %%
label_names = ["Experiment-1","Experiment-2","Experiment-3","Experiment-4"]
# auc_black_MIMIC


auc_MIMIC = {
    0: auc_all_MIMIC[5],
    1: auc_white_MIMIC[5],
    2: auc_black_MIMIC[5],
    3: auc_other_MIMIC[5],
    4: auc_male_MIMIC[5],
    5: auc_female_MIMIC[5]
}

auc_SYN = {
    0: auc_all_SYN[5],
    1: auc_white_SYN[5],
    2: auc_black_SYN[5],
    3: auc_other_SYN[5],
    4: auc_male_SYN[5],
    5: auc_female_SYN[5]
}

auc_MIMIC_CHEXPERT = {
    0: auc_all_MIMIC_CHEXPERT[5],
    1: auc_white_MIMIC_CHEXPERT[5],
    2: auc_black_MIMIC_CHEXPERT[5],
    3: auc_other_MIMIC_CHEXPERT[5],
    4: auc_male_MIMIC_CHEXPERT[5],
    5: auc_female_MIMIC_CHEXPERT[5]
}

auc_MIMIC_SYN = {
    0: auc_all_MIMIC_SYN[5],
    1: auc_white_MIMIC_SYN[5],
    2: auc_black_MIMIC_SYN[5],
    3: auc_other_MIMIC_SYN[5],
    4: auc_male_MIMIC_SYN[5],
    5: auc_female_MIMIC_SYN[5]
}

auc_CHEXPERT = {
    0: auc_all_CHEXPERT[5],
    1: auc_white_CHEXPERT[5],
    2: auc_black_CHEXPERT[5],
    3: auc_other_CHEXPERT[5],
    4: auc_male_CHEXPERT[5],
    5: auc_female_CHEXPERT[5]
}

auc_CHEXPERT_SYN = {
    0: auc_all_CHEXPERT_SYN[5],
    1: auc_white_CHEXPERT_SYN[5],
    2: auc_black_CHEXPERT_SYN[5],
    3: auc_other_CHEXPERT_SYN[5],
    4: auc_male_CHEXPERT_SYN[5],
    5: auc_female_CHEXPERT_SYN[5]
}

auc_MIMIC_75SYN = {
    0: auc_all_MIMIC_75SYN[5],
    1: auc_white_MIMIC_75SYN[5],
    2: auc_black_MIMIC_75SYN[5],
    3: auc_other_MIMIC_75SYN[5],
    4: auc_male_MIMIC_75SYN[5],
    5: auc_female_MIMIC_75SYN[5]
}

auc_MIMIC_50SYN = {
    0: auc_all_MIMIC_50SYN[5],
    1: auc_white_MIMIC_50SYN[5],
    2: auc_black_MIMIC_50SYN[5],
    3: auc_other_MIMIC_50SYN[5],
    4: auc_male_MIMIC_50SYN[5],
    5: auc_female_MIMIC_50SYN[5]
}

auc_MIMIC_25SYN = {
    0: auc_all_MIMIC_25SYN[5],
    1: auc_white_MIMIC_25SYN[5],
    2: auc_black_MIMIC_25SYN[5],
    3: auc_other_MIMIC_25SYN[5],
    4: auc_male_MIMIC_25SYN[5],
    5: auc_female_MIMIC_25SYN[5]
}

auc_MIMIC_01SYN = {
    0: auc_all_MIMIC_01SYN[5],
    1: auc_white_MIMIC_01SYN[5],
    2: auc_black_MIMIC_01SYN[5],
    3: auc_other_MIMIC_01SYN[5],
    4: auc_male_MIMIC_01SYN[5],
    5: auc_female_MIMIC_01SYN[5]
}

auc_MIMIC_05SYN = {
    0: auc_all_MIMIC_05SYN[5],
    1: auc_white_MIMIC_05SYN[5],
    2: auc_black_MIMIC_05SYN[5],
    3: auc_other_MIMIC_05SYN[5],
    4: auc_male_MIMIC_05SYN[5],
    5: auc_female_MIMIC_05SYN[5]
}

auc_MIMIC_10SYN = {
    0: auc_all_MIMIC_10SYN[5],
    1: auc_white_MIMIC_10SYN[5],
    2: auc_black_MIMIC_10SYN[5],
    3: auc_other_MIMIC_10SYN[5],
    4: auc_male_MIMIC_10SYN[5],
    5: auc_female_MIMIC_10SYN[5]
}


auc_MIMIC_SYN
# auc_MIMIC_dict = [auc_black_MIMIC[i]  for i in range(len(label_names))]
# auc_SYN_dict = [auc_black_SYN[i] for i in range(len(label_names))]
# auc_MIMIC_SYN_dict = [auc_black_MIMIC_SYN[i] for i in range(len(label_names))]
# auc_MIMIC_CHEXPERT_dict = [auc_black_MIMIC_CHEXPERT[i] for i in range(len(label_names))]
# # auc_dicts = [auc_MIMIC, auc_SYN, auc_MIMIC_SYN, auc_MIMIC_CHEXPERT]
label_names = ["MIMIC", "Synthetic", "MIMIC + CheXpert", "CheXpert", "CheXpert + SYN", "MIMIC + SYN", "MIMIC + 75% SYN", "MIMIC + 50% SYN", "MIMIC + 25% SYN", "MIMIC + 10% SYN", "MIMIC + 5% SYN", "MIMIC + 1% SYN"]
auc_dicts = [auc_MIMIC, auc_SYN, auc_MIMIC_CHEXPERT, auc_CHEXPERT, auc_CHEXPERT_SYN, auc_MIMIC_SYN, auc_MIMIC_75SYN, auc_MIMIC_50SYN, auc_MIMIC_25SYN, auc_MIMIC_10SYN, auc_MIMIC_05SYN, auc_MIMIC_01SYN]
auc_dicts
# # Plot the data
plot_auc_barchart_experiments(auc_dicts, label_names, "12 EXPERIMENTS", "AUC")


label_names = ["MIMIC", "MIMIC + Synthetic", "MIMIC + 75% Synthetic", "MIMIC + 50% Synthetic", "MIMIC + 25% Synthetic", "MIMIC + 10% Synthetic", "MIMIC + 5% Synthetic", "MIMIC + 1% Synthetic"]
auc_dicts = [auc_MIMIC, auc_MIMIC_SYN, auc_MIMIC_75SYN, auc_MIMIC_50SYN, auc_MIMIC_25SYN, auc_MIMIC_10SYN, auc_MIMIC_05SYN, auc_MIMIC_01SYN]
auc_dicts
# # Plot the data
plot_auc_barchart_experiments(auc_dicts, label_names, "[MIMIC] And All The [MIMIC + Synthetic] Experiments", "AUC")


plot_auc_barchart_experiments_gender(auc_dicts, label_names, "6 EXPERIMENTS", "AUC")
